# %%
from collections import defaultdict

# %%
def formatter(string):
    case, event = string.replace("\n","").split(",")
    return case, event

# returns a set with all the activities present in the log
# and a dictionary with each event's trace of events
# where the key of the dict is the caseId and the value
# is an array of events
def process_logs(filename):
    logs = defaultdict(list)
    events = set()
    with open(filename, "r") as logfile:
        for i in logfile.readlines()[1:]:
            case, event = formatter(i)
            logs[case].append(event)
            events.add(event)
    return events, logs

# %%
# returns a matrix filled with zeros
# with dimension equal to the event_set squared.
def zero_transition_matrix(event_set):
    event_list = list(event_set)
    event_list.sort()
    event_indexes = {event: index for index, event in enumerate(event_list)}
    event_count = len(event_list)
    matrix = [[0] * event_count for i in range(event_count)]
    return event_indexes, matrix

# %%
events, logs = process_logs("TDlog.csv")
event_indexes, transition_matrix = zero_transition_matrix(events)
def generate_succession_matrix(events, logs, window=1):
    event_indexes, transition_matrix = zero_transition_matrix(events)
    for log in logs.values():
        last_checkable_index = len(log) - window
        for index in range(0, last_checkable_index):
            predecessor = log[index]
            successor = log[index + window]
            predecessor_index = event_indexes[predecessor]
            successor_index = event_indexes[successor]
            transition_matrix[predecessor_index][successor_index] += 1
    return transition_matrix

succession_matrix = generate_succession_matrix(events, logs,1)
for letter, index in event_indexes.items():
    for letter2, index2 in event_indexes.items():
        count = succession_matrix[index][index2]
        if count > 0:
            print("{}: {} -> {}".format(letter, letter2, count))
# Out:
# A: B -> 511
# A: C -> 489
# B: D -> 499
# B: E -> 511
# C: F -> 261
# C: G -> 228
# D: B -> 499
# E: M -> 268
# E: P -> 243
# F: H -> 131
# F: I -> 130
# G: K -> 104
# G: L -> 124
# H: I -> 131
# H: J -> 130
# I: H -> 130
# I: J -> 131
# J: L -> 261
# K: L -> 104
# M: N -> 243
# M: P -> 268
# N: O -> 511
# O: Q -> 511
# P: M -> 243
# P: N -> 268
# Q: L -> 511

# %%
events, logs = process_logs("TDlog.csv")
def generate_dependancy_matrix(events, logs):
    succession_matrix = generate_succession_matrix(events, logs, 1)
    event_indexes, dependancy_matrix = zero_transition_matrix(events)
    dimension = len(succession_matrix)
    for row in range(dimension):
        for col in range(dimension):
            direct_succession = succession_matrix[row][col]
            inverse_succession = succession_matrix[col][row]
            if row == col:
                dependancy_matrix[row][col] = round((direct_succession / (direct_succession + 1)), 3)
            else:
                dependancy_matrix[row][col] = round((direct_succession - inverse_succession) / (direct_succession + inverse_succession + 1), 3)
    return dependancy_matrix
dependancy_matrix = generate_dependancy_matrix(events, logs)
for letter, index in event_indexes.items():
    for letter2, index2 in event_indexes.items():
        count = dependancy_matrix[index][index2]
        if count > 0:
            print("{}: {} -> {}".format(letter, letter2, count))
# Out:
# A: B -> 0.998
# A: C -> 0.998
# B: E -> 0.998
# C: F -> 0.996
# C: G -> 0.996
# E: M -> 0.996
# E: P -> 0.996
# F: H -> 0.992
# F: I -> 0.992
# G: K -> 0.99
# G: L -> 0.992
# H: I -> 0.004
# H: J -> 0.992
# I: J -> 0.992
# J: L -> 0.996
# K: L -> 0.99
# M: N -> 0.996
# M: P -> 0.049
# N: O -> 0.998
# O: Q -> 0.998
# P: N -> 0.996
# Q: L -> 0.998

# %%
def indexes_to_events(dictionary, transform):
    inverse = { v: k for k, v in transform.items() }
    result = {}
    for key, array in dictionary.items():
        letter = inverse[key]
        letter_array = [inverse[item] for item in array]
        result[letter] = letter_array
    return result

# %%
def is_above_thresholds(frecuency, dependancy, thresholds):
    return (frecuency > thresholds["frecuency"] and dependancy > thresholds["dependancy"])

def is_below_thresholds(frecuency, dependancy, thresholds):
    return (frecuency <= thresholds["frecuency"] and dependancy <= thresholds["dependancy"])

def is_above_frecuency_below_dependancy(frecuency, dependancy, thresholds):
    return (frecuency > thresholds["frecuency"] and dependancy <= thresholds["dependancy"])

# %%
def edges_above_threshold(edges, thresholds, succession_matrix, dependancy_matrix):
    conditions = {}
    for start, end in edges:
        frecuency = succession_matrix[start][end]
        dependancy = dependancy_matrix[start][end]
        conditions[(start, end)] = is_above_thresholds(frecuency, dependancy, thresholds)
    return conditions

def edges_below_threshold(edges, thresholds, succession_matrix, dependancy_matrix):
    conditions = {}
    for start, end in edges:
        frecuency = succession_matrix[start][end]
        dependancy = dependancy_matrix[start][end]
        conditions[(start, end)] = is_below_thresholds(frecuency, dependancy, thresholds)
    return conditions

def edges_above_frecuency_below_dependancy(edges, thresholds, succession_matrix, dependancy_matrix):
    conditions = {}
    for start, end in edges:
        frecuency = succession_matrix[start][end]
        dependancy = dependancy_matrix[start][end]
        conditions[(start, end)] = is_above_frecuency_below_dependancy(frecuency, dependancy, thresholds)
    return conditions

# %%
def find_xor_splits(event_indexes, succession_matrix, dependancy_matrix, thresholds):
    xor_nodes = defaultdict(list)
    for row in event_indexes.values():
        xor_edges = []
        for col in event_indexes.values():
            xor_edges.append([row, col])
        above_threshold = edges_above_threshold(xor_edges, thresholds, succession_matrix, dependancy_matrix)
        for edge, above in above_threshold.items():
            if above:
                xor_nodes[edge[0]].append(edge[1])
    xor_nodes = { k: v for k, v in xor_nodes.items() if len(v) > 1 }
    print("Potential XOR splits (format -> 'start: [ends]'): {}".format(indexes_to_events(xor_nodes, event_indexes)))    
    xor_filtered_nodes = xor_nodes.copy()
    for start_node, successors in xor_nodes.items():
        edges = []
        others = [start_node] + successors        
        for successor in successors:
            for other in others:
                if successor == other:
                    continue
                edges.append([successor, other])
        below_threshold = edges_below_threshold(edges, thresholds, succession_matrix, dependancy_matrix)                
        if not all(condition for condition in below_threshold.values()):
            xor_filtered_nodes.pop(start_node, None)
    print("Discovered XOR splits: {}".format(indexes_to_events(xor_filtered_nodes, event_indexes)))
    return xor_filtered_nodes

# %%
def find_xor_joins(event_indexes, succession_matrix, dependancy_matrix, thresholds):
    xor_nodes = defaultdict(list)
    for current_node in event_indexes.values():
        xor_edges = []
        for other_node in event_indexes.values():
            xor_edges.append([other_node, current_node])
        above_threshold = edges_above_threshold(xor_edges, thresholds, succession_matrix, dependancy_matrix)
        for edge, above in above_threshold.items():
            if above:
                xor_nodes[current_node].append(edge[0])
    xor_nodes = { k: v for k, v in xor_nodes.items() if len(v) > 1 }
    print("Potential XOR joins (format -> 'end: [starts]'): {}".format(indexes_to_events(xor_nodes, event_indexes)))
    xor_filtered_nodes = xor_nodes.copy()
    for end_node, predecessors in xor_nodes.items():
        edges = []
        others = [end_node] + predecessors
        for predecessor in predecessors:
            for other in others:
                if predecessor == other:
                    continue
                edges.append([other, predecessor])
        below_threshold = edges_below_threshold(edges, thresholds, succession_matrix, dependancy_matrix)
        if not all(condition for condition in below_threshold.values()):
            xor_filtered_nodes.pop(end_node, None)

    print("Discovered XOR joins: {}".format(indexes_to_events(xor_filtered_nodes, event_indexes)))            
    return xor_filtered_nodes

# %%
events, logs = process_logs("TDlog.csv")
event_indexes, zero_matrix = zero_transition_matrix(events)
succession_matrix = generate_succession_matrix(events, logs)
dependancy_matrix = generate_dependancy_matrix(events, logs)

def find_and_splits(event_indexes, succession_matrix, dependancy_matrix, thresholds):
    and_nodes = defaultdict(list)
    for row in event_indexes.values():
        and_edges = []
        for col in event_indexes.values():
            and_edges.append([row, col])
        above_threshold = edges_above_threshold(and_edges, thresholds, succession_matrix, dependancy_matrix)
        for edge, above in above_threshold.items():
            if above:
                and_nodes[edge[0]].append(edge[1])
    and_nodes = { k: v for k, v in and_nodes.items() if len(v) > 1 }
    print("Potential AND splits (format -> 'start: [ends]'): {}".format(indexes_to_events(and_nodes, event_indexes)))    
    and_filtered_nodes = and_nodes.copy()
    frecuency_thresholds = thresholds.copy()
    frecuency_thresholds['dependancy'] = -100000000
    for start_node, successors in and_nodes.items():
        parallel_edges = []
        wrong_edges = []
        conditions = {}
        others = [start_node] + successors        
        for successor in successors:
            for other in others:
                if successor == other:
                    continue
                elif other in successors:
                    parallel_edges.append([successor, other])
                else:
                    wrong_edges.append([successor, other])
        above_frecuency_threshold = edges_above_frecuency_below_dependancy(parallel_edges, thresholds, succession_matrix, dependancy_matrix)                
        below_threshold = edges_above_threshold(wrong_edges, thresholds, succession_matrix, dependancy_matrix)                        
        if not all(condition for condition in below_threshold.values()):
            and_filtered_nodes.pop(start_node, None)
        if not all(condition for condition in above_frecuency_threshold.values()):
            and_filtered_nodes.pop(start_node, None)
    print("Discovered AND splits: {}".format(indexes_to_events(and_filtered_nodes, event_indexes)))
    return and_filtered_nodes

# %%
events, logs = process_logs("TDlog.csv")
event_indexes, zero_matrix = zero_transition_matrix(events)
succession_matrix = generate_succession_matrix(events, logs)
dependancy_matrix = generate_dependancy_matrix(events, logs)

def find_and_joins(event_indexes, succession_matrix, dependancy_matrix, thresholds):
    and_nodes = defaultdict(list)
    for current_node in event_indexes.values():
        and_edges = []
        for other_node in event_indexes.values():
            and_edges.append([other_node, current_node])
        above_threshold = edges_above_threshold(and_edges, thresholds, succession_matrix, dependancy_matrix)
        for edge, above in above_threshold.items():
            if above:
                and_nodes[current_node].append(edge[0])
    and_nodes = { k: v for k, v in and_nodes.items() if len(v) > 1 }
    print("Potential AND joins (format -> 'end: [starts]'): {}".format(indexes_to_events(and_nodes, event_indexes)))
    and_filtered_nodes = and_nodes.copy()
    for end_node, predecessors in and_nodes.items():
        parallel_edges = []
        wrong_edges = []
        conditions = {}
        others = [end_node] + predecessors        
        for predecessor in predecessors:
            for other in others:
                if predecessor == other:
                    continue
                elif other in predecessors:
                    parallel_edges.append([other, predecessor])
                else:
                    wrong_edges.append([other, predecessor])
        above_frecuency_threshold = edges_above_frecuency_below_dependancy(parallel_edges, thresholds, succession_matrix, dependancy_matrix)                
        below_threshold = edges_below_threshold(wrong_edges, thresholds, succession_matrix, dependancy_matrix)                        
        if not all(condition for condition in below_threshold.values()):
            and_filtered_nodes.pop(end_node, None)
        if not all(condition for condition in above_frecuency_threshold.values()):
            and_filtered_nodes.pop(end_node, None)
    print("Discovered AND joins: {}".format(indexes_to_events(and_filtered_nodes, event_indexes)))
    return and_filtered_nodes

# %%
events, logs = process_logs("TDlog.csv")
event_indexes, zero_matrix = zero_transition_matrix(events)
succession_matrix = generate_succession_matrix(events, logs)
dependancy_matrix = generate_dependancy_matrix(events, logs)

# Setted based on observation
thresholds = {"frecuency": 100, "dependancy": 0.2}  
print("Thresholds setted at:\n\t* Frecuency: {}\n\t* Dependancy: {}\n".format(thresholds['frecuency'], thresholds['dependancy']))

xor_split_nodes = find_xor_splits(event_indexes, succession_matrix, dependancy_matrix, thresholds)
xor_join_nodes = find_xor_joins(event_indexes, succession_matrix, dependancy_matrix, thresholds)
and_split_nodes = find_and_splits(event_indexes, succession_matrix, dependancy_matrix, thresholds)
and_join_nodes = find_and_joins(event_indexes, succession_matrix, dependancy_matrix, thresholds)
# Out:
# Thresholds setted at:
# 	* Frecuency: 100
# 	* Dependancy: 0.2
#
# Potential XOR splits (format -> 'start: [ends]'): {'A': ['B', 'C'], 'C': ['F', 'G'], 'E': ['M', 'P'], 'F': ['H', 'I'], 'G': ['K', 'L']}
# Discovered XOR splits: {'A': ['B', 'C'], 'C': ['F', 'G']}
# Potential XOR joins (format -> 'end: [starts]'): {'J': ['H', 'I'], 'L': ['G', 'J', 'K', 'Q'], 'N': ['M', 'P']}
# Discovered XOR joins: {}
# Potential AND splits (format -> 'start: [ends]'): {'A': ['B', 'C'], 'C': ['F', 'G'], 'E': ['M', 'P'], 'F': ['H', 'I'], 'G': ['K', 'L']}
# Discovered AND splits: {}
# Potential AND joins (format -> 'end: [starts]'): {'J': ['H', 'I'], 'L': ['G', 'J', 'K', 'Q'], 'N': ['M', 'P']}
# Discovered AND joins: {'J': ['H', 'I'], 'N': ['M', 'P']}

# %%
events, logs = process_logs("TDlog.csv")
def loops(events, logs):
    loops_finded = {}
    for log in logs.values():
        appearances = defaultdict(int)
        for event_index in range(len(log)):
            event = log[event_index]
            appearances[event] += 1
            if appearances[event] > 1:
                loops_finded[log[event_index-1]] = log[event_index]
    return loops_finded

loops(events, logs)
# Out:
# {'D': 'B', 'B': 'D'}

# %%
a ="bcfg"
for i in logs.values():
    if "F" in i and "G" in i:
        print("no es un xor B,C")

# %%
logs
# Out:
# defaultdict(list,
#             {'372': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '659': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '632': ['A', 'C', 'G', 'L'],
#              '952': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '187': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '554': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '923': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '646': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '743': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '230': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '540': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '19': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '652': ['A', 'C', 'G', 'L'],
#              '381': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '184': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '255': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '75': ['A', 'C', 'G', 'K', 'L'],
#              '172': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '762': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '167': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '106': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '5': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '354': ['A', 'C', 'G', 'K', 'L'],
#              '385': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '356': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '866': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '928': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '594': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '661': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '136': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '815': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '695': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '69': ['A', 'C', 'G', 'K', 'L'],
#              '798': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '312': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '301': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '292': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '349': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '393': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '715': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '283': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '738': ['A', 'C', 'G', 'L'],
#              '465': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '609': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '635': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '500': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '91': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '268': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '218': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '168': ['A', 'C', 'G', 'K', 'L'],
#              '878': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '667': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '608': ['A', 'C', 'G', 'K', 'L'],
#              '979': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '327': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '498': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '658': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '717': ['A', 'C', 'G', 'L'],
#              '849': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '135': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '330': ['A', 'C', 'G', 'L'],
#              '852': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '397': ['A', 'C', 'G', 'L'],
#              '804': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '611': ['A', 'C', 'G', 'L'],
#              '391': ['A', 'C', 'G', 'L'],
#              '101': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '446': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '555': ['A', 'C', 'G', 'L'],
#              '169': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '697': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '619': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '596': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '364': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '78': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '786': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '791': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '999': ['A', 'C', 'G', 'L'],
#              '284': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '204': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '932': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '111': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '739': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '626': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '753': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '892': ['A', 'C', 'G', 'L'],
#              '921': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '53': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '243': ['A', 'C', 'G', 'L'],
#              '751': ['A', 'C', 'G', 'L'],
#              '973': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '121': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '409': ['A', 'C', 'G', 'L'],
#              '510': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '602': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '578': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '32': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '57': ['A', 'C', 'G', 'L'],
#              '252': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '131': ['A', 'C', 'G', 'L'],
#              '242': ['A', 'C', 'G', 'L'],
#              '621': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '728': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '253': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '392': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '683': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '702': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '800': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '162': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '584': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '484': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '159': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '545': ['A', 'C', 'G', 'K', 'L'],
#              '654': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '692': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '116': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '653': ['A', 'C', 'G', 'L'],
#              '995': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '816': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '68': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '117': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '315': ['A', 'C', 'G', 'K', 'L'],
#              '896': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '171': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '445': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '696': ['A', 'C', 'G', 'K', 'L'],
#              '837': ['A', 'C', 'G', 'L'],
#              '164': ['A', 'C', 'G', 'K', 'L'],
#              '971': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '809': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '258': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '211': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '875': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '335': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '359': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '680': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '147': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '741': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '290': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '201': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '477': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '170': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '49': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '358': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '420': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '435': ['A', 'C', 'G', 'K', 'L'],
#              '690': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '188': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '648': ['A', 'C', 'G', 'K', 'L'],
#              '758': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '438': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '625': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '725': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '8': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '94': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '415': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '579': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '685': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '841': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '16': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '826': ['A', 'C', 'G', 'L'],
#              '855': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '380': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '941': ['A', 'C', 'G', 'L'],
#              '994': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '115': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '129': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '378': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '132': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '655': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '835': ['A', 'C', 'G', 'K', 'L'],
#              '394': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '996': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '536': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '249': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '338': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '209': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '87': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '450': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '832': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '612': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '857': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '763': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '506': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '406': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '887': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '862': ['A', 'C', 'G', 'L'],
#              '911': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '72': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '7': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '299': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '713': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '228': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '933': ['A', 'C', 'G', 'K', 'L'],
#              '45': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '195': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '480': ['A', 'C', 'G', 'L'],
#              '257': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '58': ['A', 'C', 'G', 'K', 'L'],
#              '493': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '355': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '776': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '907': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '839': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '196': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '219': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '605': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '206': ['A', 'C', 'G', 'L'],
#              '565': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '716': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '396': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '24': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '724': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '81': ['A', 'C', 'G', 'L'],
#              '961': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '942': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '399': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '719': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '291': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '734': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '785': ['A', 'C', 'G', 'K', 'L'],
#              '643': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '886': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '803': ['A', 'C', 'G', 'L'],
#              '482': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '641': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '889': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '98': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '247': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '466': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '821': ['A', 'C', 'G', 'K', 'L'],
#              '519': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '51': ['A', 'C', 'G', 'L'],
#              '138': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '721': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '557': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '622': ['A', 'C', 'G', 'K', 'L'],
#              '497': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '85': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '366': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '198': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '344': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '244': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '616': ['A', 'C', 'G', 'L'],
#              '968': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '631': ['A', 'C', 'G', 'K', 'L'],
#              '515': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '628': ['A', 'C', 'G', 'L'],
#              '373': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '836': ['A', 'C', 'G', 'K', 'L'],
#              '733': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '105': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '598': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '347': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '452': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '183': ['A', 'C', 'G', 'L'],
#              '232': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '31': ['A', 'C', 'G', 'L'],
#              '39': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '846': ['A', 'C', 'G', 'K', 'L'],
#              '416': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '946': ['A', 'C', 'G', 'K', 'L'],
#              '694': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '389': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '670': ['A', 'C', 'G', 'K', 'L'],
#              '593': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '657': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '383': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '521': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '956': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '64': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '120': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '388': ['A', 'C', 'G', 'L'],
#              '83': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '599': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '895': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '189': ['A', 'C', 'G', 'K', 'L'],
#              '275': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '919': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '572': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '969': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '126': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '408': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '808': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '838': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '474': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '851': ['A', 'C', 'G', 'L'],
#              '229': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '471': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '827': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '2': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '15': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '151': ['A', 'C', 'G', 'K', 'L'],
#              '231': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '143': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '853': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '546': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '682': ['A', 'C', 'G', 'K', 'L'],
#              '439': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '864': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '491': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '161': ['A', 'C', 'G', 'L'],
#              '419': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '603': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '398': ['A', 'C', 'G', 'K', 'L'],
#              '310': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '361': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '985': ['A', 'C', 'G', 'K', 'L'],
#              '34': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '59': ['A', 'C', 'G', 'K', 'L'],
#              '178': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '675': ['A', 'C', 'G', 'L'],
#              '927': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '322': ['A', 'C', 'G', 'K', 'L'],
#              '607': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '760': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '38': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '175': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '496': ['A', 'C', 'G', 'L'],
#              '813': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '998': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '426': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '437': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '133': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '197': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '779': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '82': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '400': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '825': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '766': ['A', 'C', 'G', 'L'],
#              '774': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '93': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '281': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '264': ['A', 'C', 'G', 'K', 'L'],
#              '894': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '850': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '663': ['A', 'C', 'G', 'L'],
#              '182': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '666': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '35': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '475': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '797': ['A', 'C', 'G', 'K', 'L'],
#              '656': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '537': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '830': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '103': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '48': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '854': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '73': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '261': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '876': ['A', 'C', 'G', 'K', 'L'],
#              '796': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '192': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '60': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '374': ['A', 'C', 'G', 'K', 'L'],
#              '514': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '348': ['A', 'C', 'G', 'K', 'L'],
#              '962': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '601': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '890': ['A', 'C', 'G', 'K', 'L'],
#              '959': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '900': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '916': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '360': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '449': ['A', 'C', 'G', 'L'],
#              '770': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '246': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '379': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '279': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '342': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '525': ['A', 'C', 'G', 'L'],
#              '563': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '444': ['A', 'C', 'G', 'K', 'L'],
#              '691': ['A', 'C', 'G', 'K', 'L'],
#              '23': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '920': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '37': ['A', 'C', 'G', 'K', 'L'],
#              '226': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '486': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '934': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '944': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '805': ['A', 'C', 'G', 'K', 'L'],
#              '387': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '681': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '304': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '488': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '548': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '750': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '110': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '145': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '737': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '492': ['A', 'C', 'G', 'L'],
#              '368': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '811': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '693': ['A', 'C', 'G', 'L'],
#              '150': ['A', 'C', 'G', 'K', 'L'],
#              '280': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '730': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '36': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '166': ['A', 'C', 'G', 'K', 'L'],
#              '700': ['A', 'C', 'G', 'K', 'L'],
#              '860': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '752': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '992': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '140': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '502': ['A', 'C', 'G', 'L'],
#              '689': ['A', 'C', 'G', 'L'],
#              '642': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '174': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '158': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '633': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '993': ['A', 'C', 'G', 'L'],
#              '309': ['A', 'C', 'G', 'K', 'L'],
#              '317': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '674': ['A', 'C', 'G', 'L'],
#              '749': ['A', 'C', 'G', 'K', 'L'],
#              '976': ['A', 'C', 'G', 'L'],
#              '559': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '754': ['A', 'C', 'G', 'K', 'L'],
#              '376': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '893': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '822': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '513': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '520': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '589': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '948': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '922': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '193': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '47': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '50': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '558': ['A', 'C', 'G', 'L'],
#              '650': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '236': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '711': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '297': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '585': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '250': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '543': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '149': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '843': ['A', 'C', 'G', 'L'],
#              '102': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '647': ['A', 'C', 'G', 'L'],
#              '972': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '395': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '644': ['A', 'C', 'G', 'L'],
#              '295': ['A', 'C', 'G', 'K', 'L'],
#              '345': ['A', 'C', 'G', 'L'],
#              '234': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '460': ['A', 'C', 'G', 'K', 'L'],
#              '314': ['A', 'C', 'G', 'L'],
#              '176': ['A', 'C', 'G', 'L'],
#              '651': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '834': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '382': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '504': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '590': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '386': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '254': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '671': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '269': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '457': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '706': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '772': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '600': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '282': ['A', 'C', 'G', 'K', 'L'],
#              '112': ['A', 'C', 'G', 'L'],
#              '180': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '256': ['A', 'C', 'G', 'L'],
#              '509': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '128': ['A', 'C', 'G', 'K', 'L'],
#              '833': ['A', 'C', 'G', 'L'],
#              '906': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '926': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '412': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '443': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '12': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '929': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '402': ['A', 'C', 'G', 'K', 'L'],
#              '454': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '840': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '870': ['A', 'C', 'G', 'K', 'L'],
#              '745': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '0': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '423': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '705': ['A', 'C', 'G', 'L'],
#              '817': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '819': ['A', 'C', 'G', 'K', 'L'],
#              '949': ['A', 'C', 'G', 'L'],
#              '157': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '285': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '672': ['A', 'C', 'G', 'K', 'L'],
#              '531': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '759': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '25': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '569': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '861': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '458': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '726': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '802': ['A', 'C', 'G', 'L'],
#              '576': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '898': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '414': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '22': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '108': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '518': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '571': ['A', 'C', 'G', 'K', 'L'],
#              '732': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '240': ['A', 'C', 'G', 'K', 'L'],
#              '107': ['A', 'C', 'G', 'K', 'L'],
#              '918': ['A',
#               'B',
#               'D',
#               'B',
# ...
#              '722': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '984': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '191': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '185': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '160': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '97': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '369': ['A', 'C', 'G', 'K', 'L'],
#              '142': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '723': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '472': ['A', 'C', 'G', 'L'],
#              '586': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '940': ['A', 'C', 'G', 'K', 'L'],
#              '747': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '904': ['A', 'C', 'G', 'K', 'L'],
#              '573': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '65': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '538': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '403': ['A', 'C', 'G', 'L'],
#              '507': ['A', 'C', 'G', 'L'],
#              '96': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '561': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '70': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '844': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '544': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '62': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '331': ['A', 'C', 'G', 'K', 'L'],
#              '436': ['A', 'C', 'G', 'K', 'L'],
#              '109': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '768': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '720': ['A', 'C', 'G', 'K', 'L'],
#              '665': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '300': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '401': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '210': ['A', 'C', 'G', 'K', 'L'],
#              '404': ['A', 'C', 'G', 'L'],
#              '828': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '829': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '967': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '824': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '4': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '977': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '329': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '433': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '139': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '447': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '43': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '869': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '980': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '787': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '463': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '238': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '490': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '214': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '99': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '872': ['A', 'C', 'G', 'L'],
#              '627': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '377': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '964': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '353': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '42': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '430': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '473': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '287': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '989': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '963': ['A', 'C', 'G', 'L'],
#              '925': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '67': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '333': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '418': ['A', 'C', 'G', 'K', 'L'],
#              '704': ['A', 'C', 'G', 'L'],
#              '427': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '873': ['A', 'C', 'G', 'K', 'L'],
#              '52': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '624': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '769': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '746': ['A', 'C', 'G', 'L'],
#              '793': ['A', 'C', 'G', 'L'],
#              '336': ['A', 'C', 'G', 'L'],
#              '679': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '351': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '597': ['A', 'C', 'G', 'L'],
#              '917': ['A', 'C', 'G', 'L'],
#              '303': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '417': ['A', 'C', 'G', 'L'],
#              '424': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '997': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '325': ['A', 'C', 'G', 'K', 'L'],
#              '177': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '222': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '947': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '30': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '362': ['A', 'C', 'G', 'K', 'L'],
#              '556': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '235': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '552': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '960': ['A', 'C', 'G', 'L'],
#              '698': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '945': ['A', 'C', 'G', 'L'],
#              '820': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '924': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '542': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '152': ['A', 'C', 'G', 'L'],
#              '339': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '831': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '574': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '76': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '61': ['A', 'C', 'G', 'K', 'L'],
#              '319': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '179': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '346': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '637': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '688': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '155': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '123': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '294': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '863': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '324': ['A', 'C', 'G', 'L'],
#              '953': ['A', 'C', 'G', 'K', 'L'],
#              '511': ['A', 'C', 'G', 'K', 'L'],
#              '935': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '778': ['A', 'C', 'G', 'K', 'L'],
#              '781': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '217': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '810': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '66': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '13': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '550': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '764': ['A', 'C', 'G', 'L'],
#              '71': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '748': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '127': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '712': ['A', 'C', 'G', 'K', 'L'],
#              '676': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '495': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '587': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '588': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '216': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '265': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '678': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '845': ['A', 'C', 'G', 'L'],
#              '983': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '614': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '788': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '617': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '245': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '273': ['A', 'C', 'G', 'K', 'L'],
#              '858': ['A', 'C', 'G', 'K', 'L'],
#              '237': ['A', 'C', 'G', 'L'],
#              '669': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '77': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '522': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '707': ['A', 'C', 'G', 'L'],
#              '974': ['A', 'C', 'G', 'K', 'L'],
#              '567': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '801': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '868': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '286': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '455': ['A', 'C', 'G', 'L'],
#              '215': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '6': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '604': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '29': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '80': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '321': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '709': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '429': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '508': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '316': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '547': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '583': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '534': ['A', 'C', 'G', 'L'],
#              '478': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '736': ['A', 'C', 'G', 'L'],
#              '14': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '469': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '181': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '241': ['A', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '501': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '812': ['A', 'C', 'G', 'L'],
#              '46': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '225': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '453': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '357': ['A', 'C', 'G', 'K', 'L'],
#              '84': ['A', 'B', 'D', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '307': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '950': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'M',
#               'P',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '341': ['A',
#               'B',
#               'D',
#               'B',
#               'D',
#               'B',
#               'E',
#               'P',
#               'M',
#               'N',
#               'O',
#               'Q',
#               'L'],
#              '792': ['A', 'C', 'G', 'K', 'L'],
#              '487': ['A', 'B', 'E', 'M', 'P', 'N', 'O', 'Q', 'L'],
#              '951': ['A', 'B', 'D', 'B', 'E', 'P', 'M', 'N', 'O', 'Q', 'L'],
#              '915': ['A', 'C', 'F', 'I', 'H', 'J', 'L'],
#              '262': ['A', 'C', 'G', 'L'],
#              '119': ['A', 'C', 'F', 'H', 'I', 'J', 'L'],
#              '553': ['A', 'C', 'G', 'L']})
